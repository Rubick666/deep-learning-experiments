# %%
from keras.datasets import mnist
import numpy as np
from keras.losses import binary_crossentropy
from keras import layers
from keras.models import Model

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %%
enc_dim = 32

inputImg = layers.Input(shape=(784,))
encoLayer = layers.Dense(enc_dim, activation='relu')(inputImg)
decoLayer = layers.Dense(784, activation='sigmoid')(encoLayer)

AE_model = Model(inputImg, decoLayer)

AE_model.compile(optimizer='adam', loss=binary_crossentropy)

# %%
num_epochs = 100
AE_model.fit(x_train, x_train, batch_size=256, shuffle=True, epochs=num_epochs, validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.3831 - val_loss: 0.1915
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.1818 - val_loss: 0.1554
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1506 - val_loss: 0.1347
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1322 - val_loss: 0.1219
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1205 - val_loss: 0.1133
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1129 - val_loss: 0.1072
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1073 - val_loss: 0.1029
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1033 - val_loss: 0.0997
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1001 - val_loss: 0.0974
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0982 - val_loss: 0.0959
# Epoch 11/100
# ...
